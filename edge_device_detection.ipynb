# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.4.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiofiles==22.1.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: aiohttp==3.9.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: aiohttp-cors==0.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: aiosignal==1.3.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: aiosqlite==0.19.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.19.0)
# Requirement already satisfied: anyio==4.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: astroid==3.0.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: asttokens==2.4.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.4.1)
# Requirement already satisfied: async-timeout==4.0.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (4.0.3)
# Requirement already satisfied: attrs==23.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (23.2.0)
# Requirement already satisfied: autopep8==2.0.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.0.4)
# Requirement already satisfied: Babel==2.14.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (2.14.0)
# Requirement already satisfied: bcrypt==4.1.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (4.1.2)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (4.12.3)
# Requirement already satisfied: black==23.12.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (23.12.1)
# Requirement already satisfied: bleach==6.1.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (6.1.0)
# Requirement already satisfied: blessed==1.20.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (1.20.0)
# Requirement already satisfied: bokeh==3.3.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (3.3.3)
# Requirement already satisfied: boto3==1.28.85 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.28.85)
# Requirement already satisfied: botocore==1.31.85 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.31.85)
# Requirement already satisfied: cachetools==5.3.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (5.3.2)
# Requirement already satisfied: certifi==2023.11.17 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (2023.11.17)
# Requirement already satisfied: cffi==1.16.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (1.16.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (8.1.7)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.2.1)
# Requirement already satisfied: cmake==3.28.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (3.28.1)
# Requirement already satisfied: codeflare-sdk==0.12.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.12.1)
# Requirement already satisfied: codeflare-torchx==0.6.0.dev1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.6.0.dev1)
# Requirement already satisfied: colorama==0.4.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.4.6)
# Requirement already satisfied: colorful==0.5.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.5.6)
# Requirement already satisfied: comm==0.2.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.2.1)
# Requirement already satisfied: commonmark==0.9.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.9.1)
# Requirement already satisfied: contourpy==1.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (1.2.0)
# Requirement already satisfied: cryptography==40.0.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (40.0.2)
# Requirement already satisfied: cycler==0.12.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (1.8.0)
# Requirement already satisfied: decorator==5.1.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (0.7.1)
# Requirement already satisfied: Deprecated==1.2.14 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (1.2.14)
# Requirement already satisfied: deprecation==2.1.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: dill==0.3.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (0.3.7)
# Requirement already satisfied: distlib==0.3.8 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 47)) (0.3.8)
# Requirement already satisfied: dnspython==2.5.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 48)) (2.5.0)
# Requirement already satisfied: docker==7.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 49)) (7.0.0)
# Requirement already satisfied: docstring-to-markdown==0.13 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (0.13)
# Requirement already satisfied: docstring_parser==0.8.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 51)) (0.8.1)
# Requirement already satisfied: elyra-code-snippet-extension==3.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 52)) (3.15.0)
# Requirement already satisfied: elyra-pipeline-editor-extension==3.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 53)) (3.15.0)
# Requirement already satisfied: elyra-python-editor-extension==3.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 54)) (3.15.0)
# Requirement already satisfied: elyra-server==3.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 55)) (3.15.0)
# Requirement already satisfied: entrypoints==0.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 56)) (0.4)
# Requirement already satisfied: exceptiongroup==1.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (1.2.0)
# Requirement already satisfied: executing==1.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.19.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 59)) (2.19.1)
# Requirement already satisfied: filelock==3.13.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 60)) (3.13.1)
# Requirement already satisfied: fire==0.5.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 61)) (0.5.0)
# Requirement already satisfied: flake8==7.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 62)) (7.0.0)
# Requirement already satisfied: fonttools==4.47.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 63)) (4.47.2)
# Requirement already satisfied: fqdn==1.5.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 64)) (1.5.1)
# Requirement already satisfied: frozenlist==1.4.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 65)) (1.4.1)
# Requirement already satisfied: fsspec==2023.12.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 66)) (2023.12.2)
# Requirement already satisfied: gitdb==4.0.11 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 67)) (4.0.11)
# Requirement already satisfied: GitPython==3.1.41 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 68)) (3.1.41)
# Requirement already satisfied: google-api-core==2.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 69)) (2.15.0)
# Requirement already satisfied: google-api-python-client==1.12.11 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 70)) (1.12.11)
# Requirement already satisfied: google-auth==2.27.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 71)) (2.27.0)
# Requirement already satisfied: google-auth-httplib2==0.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 72)) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 73)) (1.0.0)
# Requirement already satisfied: google-cloud-core==2.4.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 74)) (2.4.1)
# Requirement already satisfied: google-cloud-storage==2.14.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 75)) (2.14.0)
# Requirement already satisfied: google-crc32c==1.5.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 76)) (1.5.0)
# Requirement already satisfied: google-resumable-media==2.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 77)) (2.7.0)
# Requirement already satisfied: googleapis-common-protos==1.62.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 78)) (1.62.0)
# Requirement already satisfied: gpustat==1.1.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 79)) (1.1.1)
# Requirement already satisfied: grpcio==1.60.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 80)) (1.60.0)
# Requirement already satisfied: httplib2==0.22.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 81)) (0.22.0)
# Requirement already satisfied: idna==3.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 82)) (3.6)
# Requirement already satisfied: importlib-metadata==7.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 83)) (7.0.1)
# Requirement already satisfied: ipykernel==6.29.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 84)) (6.29.0)
# Requirement already satisfied: ipython==8.18.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 85)) (8.18.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 86)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.1.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 87)) (8.1.1)
# Requirement already satisfied: isoduration==20.11.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 88)) (20.11.0)
# Requirement already satisfied: isort==5.13.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 89)) (5.13.2)
# Requirement already satisfied: jedi==0.19.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 90)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 91)) (3.1.3)
# Requirement already satisfied: jmespath==1.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 92)) (1.0.1)
# Requirement already satisfied: joblib==1.3.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 93)) (1.3.2)
# Requirement already satisfied: json5==0.9.14 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 94)) (0.9.14)
# Requirement already satisfied: jsonpointer==2.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 95)) (2.4)
# Requirement already satisfied: jsonschema==4.21.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 96)) (4.21.1)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 97)) (2023.12.1)
# Requirement already satisfied: jupyter-bokeh==3.0.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 98)) (3.0.7)
# Requirement already satisfied: jupyter-events==0.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 99)) (0.9.0)
# Requirement already satisfied: jupyter-lsp==2.2.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 100)) (2.2.2)
# Requirement already satisfied: jupyter-resource-usage==1.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 101)) (1.0.1)
# Requirement already satisfied: jupyter-server-mathjax==0.2.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 102)) (0.2.6)
# Requirement already satisfied: jupyter-ydoc==0.2.5 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 103)) (0.2.5)
# Requirement already satisfied: jupyter_client==7.4.9 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 104)) (7.4.9)
# Requirement already satisfied: jupyter_core==5.7.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 105)) (5.7.1)
# Requirement already satisfied: jupyter_packaging==0.12.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 106)) (0.12.3)
# Requirement already satisfied: jupyter_server==2.7.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 107)) (2.7.3)
# Requirement already satisfied: jupyter_server_fileid==0.9.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 108)) (0.9.1)
# Requirement already satisfied: jupyter_server_proxy==4.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 109)) (4.0.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 110)) (0.4.4)
# Requirement already satisfied: jupyter_server_ydoc==0.8.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 111)) (0.8.0)
# Requirement already satisfied: jupyterlab==3.6.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 112)) (3.6.7)
# Requirement already satisfied: jupyterlab-lsp==4.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 113)) (4.2.0)
# Requirement already satisfied: jupyterlab-widgets==3.0.9 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 114)) (3.0.9)
# Requirement already satisfied: jupyterlab_git==0.42.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 115)) (0.42.0)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 116)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.25.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 117)) (2.25.2)
# Requirement already satisfied: kafka-python==2.0.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 118)) (2.0.2)
# Requirement already satisfied: kfp==1.8.22 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 119)) (1.8.22)
# Requirement already satisfied: kfp-pipeline-spec==0.1.16 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 120)) (0.1.16)
# Requirement already satisfied: kfp-server-api==1.8.5 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 121)) (1.8.5)
# Requirement already satisfied: kfp-tekton==1.5.9 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 122)) (1.5.9)
# Requirement already satisfied: kiwisolver==1.4.5 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 123)) (1.4.5)
# Requirement already satisfied: kubernetes==25.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 124)) (25.3.0)
# Requirement already satisfied: lit==17.0.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 125)) (17.0.6)
# Requirement already satisfied: Markdown==3.5.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 126)) (3.5.2)
# Requirement already satisfied: MarkupSafe==2.1.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 127)) (2.1.4)
# Requirement already satisfied: matplotlib==3.6.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 128)) (3.6.3)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 129)) (0.1.6)
# Requirement already satisfied: mccabe==0.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 130)) (0.7.0)
# Requirement already satisfied: micropipenv==1.6.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 131)) (1.6.0)
# Requirement already satisfied: minio==7.2.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 132)) (7.2.3)
# Requirement already satisfied: mistune==3.0.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 133)) (3.0.2)
# Requirement already satisfied: mpmath==1.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 134)) (1.3.0)
# Requirement already satisfied: msgpack==1.0.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 135)) (1.0.7)
# Requirement already satisfied: multidict==6.0.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 136)) (6.0.4)
# Requirement already satisfied: mypy-extensions==1.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 137)) (1.0.0)
# Requirement already satisfied: mysql-connector-python==8.0.33 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 138)) (8.0.33)
# Requirement already satisfied: nbclassic==1.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 139)) (1.0.0)
# Requirement already satisfied: nbclient==0.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 140)) (0.9.0)
# Requirement already satisfied: nbconvert==7.14.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 141)) (7.14.2)
# Requirement already satisfied: nbdime==3.2.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 142)) (3.2.1)
# Requirement already satisfied: nbformat==5.9.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 143)) (5.9.2)
# Requirement already satisfied: nbgitpuller==1.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 144)) (1.2.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 145)) (1.6.0)
# Requirement already satisfied: networkx==3.2.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 146)) (3.2.1)
# Requirement already satisfied: notebook==6.5.6 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 147)) (6.5.6)
# Requirement already satisfied: notebook_shim==0.2.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 148)) (0.2.3)
# Requirement already satisfied: numpy==1.24.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 149)) (1.24.4)
# Requirement already satisfied: nvidia-ml-py==12.535.133 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 150)) (12.535.133)
# Requirement already satisfied: oauthlib==3.2.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 151)) (3.2.2)
# Requirement already satisfied: onnx==1.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 152)) (1.15.0)
# Requirement already satisfied: onnxconverter-common==1.14.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 153)) (1.14.0)
# Requirement already satisfied: opencensus==0.11.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 154)) (0.11.4)
# Requirement already satisfied: opencensus-context==0.1.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 155)) (0.1.3)
# Requirement already satisfied: openshift-client==1.0.18 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 156)) (1.0.18)
# Requirement already satisfied: overrides==7.6.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 157)) (7.6.0)
# Requirement already satisfied: packaging==23.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 158)) (23.2)
# Requirement already satisfied: pandas==1.5.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 159)) (1.5.3)
# Requirement already satisfied: pandocfilters==1.5.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 160)) (1.5.1)
# Requirement already satisfied: papermill==2.5.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 161)) (2.5.0)
# Requirement already satisfied: paramiko==3.4.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 162)) (3.4.0)
# Requirement already satisfied: parso==0.8.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 163)) (0.8.3)
# Requirement already satisfied: pathspec==0.12.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 164)) (0.12.1)
# Requirement already satisfied: pexpect==4.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 165)) (4.9.0)
# Requirement already satisfied: pillow==10.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 166)) (10.2.0)
# Requirement already satisfied: platformdirs==3.11.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 167)) (3.11.0)
# Requirement already satisfied: plotly==5.16.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 168)) (5.16.1)
# Requirement already satisfied: pluggy==1.4.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 169)) (1.4.0)
# Requirement already satisfied: prometheus-client==0.19.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 170)) (0.19.0)
# Requirement already satisfied: prompt-toolkit==3.0.43 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 171)) (3.0.43)
# Requirement already satisfied: protobuf==3.20.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 172)) (3.20.2)
# Requirement already satisfied: psutil==5.9.8 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 173)) (5.9.8)
# Requirement already satisfied: psycopg==3.1.17 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 174)) (3.1.17)
# Requirement already satisfied: ptyprocess==0.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 175)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 176)) (0.2.2)
# Requirement already satisfied: py-spy==0.3.14 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 177)) (0.3.14)
# Requirement already satisfied: pyasn1==0.5.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 178)) (0.5.1)
# Requirement already satisfied: pyasn1-modules==0.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 179)) (0.3.0)
# Requirement already satisfied: pycocotools==2.0.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 180)) (2.0.7)
# Requirement already satisfied: pycodestyle==2.11.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 181)) (2.11.1)
# Requirement already satisfied: pycparser==2.21 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 182)) (2.21)
# Requirement already satisfied: pycryptodome==3.20.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 183)) (3.20.0)
# Requirement already satisfied: pydantic==1.10.14 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 184)) (1.10.14)
# Requirement already satisfied: pydocstyle==6.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 185)) (6.3.0)
# Requirement already satisfied: pyflakes==3.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 186)) (3.2.0)
# Requirement already satisfied: PyGithub==2.1.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 187)) (2.1.1)
# Requirement already satisfied: Pygments==2.17.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 188)) (2.17.2)
# Requirement already satisfied: PyJWT==2.8.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 189)) (2.8.0)
# Requirement already satisfied: pylint==3.0.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 190)) (3.0.3)
# Requirement already satisfied: pymongo==4.5.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 191)) (4.5.0)
# Requirement already satisfied: PyNaCl==1.5.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 192)) (1.5.0)
# Requirement already satisfied: pyodbc==4.0.39 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 193)) (4.0.39)
# Requirement already satisfied: pyparsing==3.1.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 194)) (3.1.1)
# Requirement already satisfied: pyre-extensions==0.0.30 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 195)) (0.0.30)
# Requirement already satisfied: python-dateutil==2.8.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 196)) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.7 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 197)) (2.0.7)
# Requirement already satisfied: python-lsp-jsonrpc==1.1.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 198)) (1.1.2)
# Requirement already satisfied: python-lsp-server==1.10.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 199)) (1.10.0)
# Requirement already satisfied: pytoolconfig==1.3.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 200)) (1.3.1)
# Requirement already satisfied: pytz==2023.3.post1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 201)) (2023.3.post1)
# Requirement already satisfied: PyYAML==6.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 202)) (6.0.1)
# Requirement already satisfied: pyzmq==24.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 203)) (24.0.1)
# Requirement already satisfied: ray==2.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 204)) (2.7.0)
# Requirement already satisfied: referencing==0.32.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 205)) (0.32.1)
# Requirement already satisfied: requests==2.31.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 206)) (2.31.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 207)) (1.3.1)
# Requirement already satisfied: requests-toolbelt==0.10.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 208)) (0.10.1)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 209)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 210)) (0.1.1)
# Requirement already satisfied: rich==12.6.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 211)) (12.6.0)
# Requirement already satisfied: rope==1.12.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 212)) (1.12.0)
# Requirement already satisfied: rpds-py==0.17.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 213)) (0.17.1)
# Requirement already satisfied: rsa==4.9 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 214)) (4.9)
# Requirement already satisfied: s3transfer==0.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 215)) (0.7.0)
# Requirement already satisfied: scikit-learn==1.3.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 216)) (1.3.2)
# Requirement already satisfied: scipy==1.11.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 217)) (1.11.4)
# Requirement already satisfied: Send2Trash==1.8.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 218)) (1.8.2)
# Requirement already satisfied: simpervisor==1.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 219)) (1.0.0)
# Requirement already satisfied: six==1.16.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 220)) (1.16.0)
# Requirement already satisfied: skl2onnx==1.15.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 221)) (1.15.0)
# Requirement already satisfied: smart-open==6.4.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 222)) (6.4.0)
# Requirement already satisfied: smmap==5.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 223)) (5.0.1)
# Requirement already satisfied: sniffio==1.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 224)) (1.3.0)
# Requirement already satisfied: snowballstemmer==2.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 225)) (2.2.0)
# Requirement already satisfied: soupsieve==2.5 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 226)) (2.5)
# Requirement already satisfied: stack-data==0.6.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 227)) (0.6.3)
# Requirement already satisfied: strip-hints==0.1.10 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 228)) (0.1.10)
# Requirement already satisfied: sympy==1.12 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 229)) (1.12)
# Requirement already satisfied: tabulate==0.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 230)) (0.9.0)
# Requirement already satisfied: tenacity==8.2.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 231)) (8.2.3)
# Requirement already satisfied: tensorboard==2.13.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 232)) (2.13.0)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 233)) (0.7.2)
# Requirement already satisfied: termcolor==2.4.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 234)) (2.4.0)
# Requirement already satisfied: terminado==0.18.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 235)) (0.18.0)
# Requirement already satisfied: threadpoolctl==3.2.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 236)) (3.2.0)
# Requirement already satisfied: tinycss2==1.2.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 237)) (1.2.1)
# Requirement already satisfied: toml==0.10.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 238)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 239)) (2.0.1)
# Requirement already satisfied: tomlkit==0.12.3 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 240)) (0.12.3)
# Requirement already satisfied: torch==2.0.1+cu118 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 241)) (2.0.1+cu118)
# Requirement already satisfied: torchvision==0.15.2+cu118 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 242)) (0.15.2+cu118)
# Requirement already satisfied: tornado==6.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 243)) (6.4)
# Requirement already satisfied: tqdm==4.66.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 244)) (4.66.1)
# Requirement already satisfied: traitlets==5.14.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 245)) (5.14.1)
# Requirement already satisfied: triton==2.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 246)) (2.0.0)
# Requirement already satisfied: typer==0.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 247)) (0.9.0)
# Requirement already satisfied: types-python-dateutil==2.8.19.20240106 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 248)) (2.8.19.20240106)
# Requirement already satisfied: typing-inspect==0.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 249)) (0.9.0)
# Requirement already satisfied: typing_extensions==4.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 250)) (4.9.0)
# Requirement already satisfied: ujson==5.9.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 251)) (5.9.0)
# Requirement already satisfied: uri-template==1.3.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 252)) (1.3.0)
# Requirement already satisfied: uritemplate==3.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 253)) (3.0.1)
# Requirement already satisfied: urllib3==1.26.18 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 254)) (1.26.18)
# Requirement already satisfied: virtualenv==20.21.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 255)) (20.21.0)
# Requirement already satisfied: watchdog==3.0.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 256)) (3.0.0)
# Requirement already satisfied: wcwidth==0.2.13 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 257)) (0.2.13)
# Requirement already satisfied: webcolors==1.13 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 258)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 259)) (0.5.1)
# Requirement already satisfied: websocket-client==1.7.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 260)) (1.7.0)
# Requirement already satisfied: Werkzeug==3.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 261)) (3.0.1)
# Requirement already satisfied: whatthepatch==1.0.5 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 262)) (1.0.5)
# Requirement already satisfied: widgetsnbextension==4.0.9 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 263)) (4.0.9)
# Requirement already satisfied: wrapt==1.16.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 264)) (1.16.0)
# Requirement already satisfied: xyzservices==2023.10.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 265)) (2023.10.1)
# Requirement already satisfied: y-py==0.6.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 266)) (0.6.2)
# Requirement already satisfied: yapf==0.40.2 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 267)) (0.40.2)
# Requirement already satisfied: yarl==1.9.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 268)) (1.9.4)
# Requirement already satisfied: yaspin==3.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 269)) (3.0.1)
# Requirement already satisfied: ypy-websocket==0.8.4 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 270)) (0.8.4)
# Requirement already satisfied: zipp==3.17.0 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 271)) (3.17.0)
# Requirement already satisfied: wheel in /opt/app-root/lib/python3.9/site-packages (from jupyter_packaging==0.12.3->-r requirements.txt (line 106)) (0.41.3)
# Requirement already satisfied: setuptools>=60.2.0 in /opt/app-root/lib/python3.9/site-packages (from jupyter_packaging==0.12.3->-r requirements.txt (line 106)) (68.1.2)
# Requirement already satisfied: pip>=9 in /opt/app-root/lib/python3.9/site-packages (from micropipenv==1.6.0->-r requirements.txt (line 131)) (22.2.2)
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import json
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import CocoDetection
from torch.utils.data import DataLoader
import numpy as np
import torch.nn.functional as F

# %% [markdown]
# ## Hyperparameters:
# - `num_epochs (10)`: Defines the total number of training cycles the model goes through the entire dataset. It affects how well the model learns from the data. Increasing this number gives the model more opportunities to update its weights but can lead to overfitting if too high.
# - `batch_size (4`): The number of training examples utilized in one iteration to update the model's weights. A smaller batch size may lead to faster convergence but can be noisy, whereas a larger batch size offers a more accurate estimate of the dataset's gradient, at the cost of higher computational expense.
# - `learning_rate (0.001)`: Controls the size of the step the model takes during the optimization of its weights. A higher learning rate can cause the model to converge quickly but may overshoot the minimum, while a lower learning rate ensures more precise convergence at the risk of getting stuck or taking too long to converge.

# %%
num_epochs = 10
batch_size = 4
learning_rate = 0.001

# %% [markdown]
# ## Transformations
# The transformation sequence applied to preprocess input data includes resizing images, converting them to PyTorch tensors, and normalizing their pixel values. This process ensures consistency and optimal conditions for model training.
#
# ### Components of the Transformation Sequence:
# - **Resize to 224x224 Pixels:** Ensures all images have a uniform size, which is necessary for models that require specific input dimensions.
# - **Conversion to PyTorch Tensors:** Transforms images from a traditional height x width x channels format to a tensor format with channels first. This step also scales pixel values to a [0, 1] range, making them suitable for model processing.
# - **Normalization:** Adjusts the pixel values based on predetermined mean and standard deviation values for each of the RGB channels. This step is crucial for aligning the input data with the conditions expected by models trained on similar datasets. Normalization helps in stabilizing learning and can lead to faster convergence and improved model performance.
#
# These preprocessing steps are critical for preparing the data, ensuring that it meets the model's requirements and is in a form that facilitates efficient learning.

# %%
# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to 224x224 pixels
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization
])

# %% [markdown]
# ## Load COCO Dataset
# The COCO dataset is utilized for training and testing, involving object detection and segmentation. It includes specifying paths to image directories and their corresponding annotation files in COCO JSON format. The same transformations are applied to both datasets to ensure consistency.
#
# ### Key Points:
# - **Training and Testing Datasets:** Both datasets are prepared with a series of transformations to format the data correctly for the model, involving resizing, converting to tensors, and normalizing.
# - **Annotations:** The COCO JSON format annotations provide detailed object information, crucial for tasks like object detection.
#
# This setup aims to standardize data preparation for effective model training and evaluation, using the widely recognized COCO format for object detection tasks.

# %%
train_dataset = CocoDetection(root='./dataset/ZiggoPortStatus-2/train', annFile='./dataset/ZiggoPortStatus-2/train/_annotations.coco.json', transform=transform)
test_dataset = CocoDetection(root='./dataset/ZiggoPortStatus-2/test', annFile='./dataset/ZiggoPortStatus-2/test/_annotations.coco.json', transform=transform)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
# Print one image
image, annotations = train_dataset[0]  # Change the index as needed
print(f"Image shape: {image.shape}, Annotations: {annotations}")
# Out:
# Image shape: torch.Size([3, 224, 224]), Annotations: [{'id': 0, 'image_id': 0, 'category_id': 4, 'bbox': [261, 120, 57.5, 40], 'area': 2300, 'segmentation': [], 'iscrowd': 0}, {'id': 1, 'image_id': 0, 'category_id': 4, 'bbox': [250, 155, 81.5, 32.5], 'area': 2648.75, 'segmentation': [], 'iscrowd': 0}, {'id': 2, 'image_id': 0, 'category_id': 2, 'bbox': [260, 199, 61, 40.5], 'area': 2470.5, 'segmentation': [], 'iscrowd': 0}, {'id': 3, 'image_id': 0, 'category_id': 2, 'bbox': [256, 235, 59, 30.5], 'area': 1799.5, 'segmentation': [], 'iscrowd': 0}]

# %% [markdown]
# This section calculates and displays the maximum number of labels (annotations) present in a single image within the training dataset. This value, max_labels, is used to determine the necessary amount of padding for uniformity across all input data instances when preparing the dataset for training a model. This step ensures that each input has the same dimensions by padding shorter sequences of labels to match the longest one.

# %%
# Get the maximum number of labels for padding
max_labels = max(len(ann) for _, ann in train_dataset)
print(f"\nmax_labels is {max_labels}")
# Out:
# max_labels is 6

# %% [markdown]
# This snippet loads category information from a COCO-format annotation file and extracts class names and their IDs. It then prints a list of detected classes, such as "Port-Status", "Eth-Conn", "Eth-Not-Conn", "TEL-Conn", and "TEL-Not-Conn", demonstrating the variety of objects recognized in the dataset.

# %%
# Load category information
with open('./dataset/ZiggoPortStatus-2/train/_annotations.coco.json', 'r') as f:
    coco_info = json.load(f)

# Get the class names
class_names = {cat['id']: cat['name'] for cat in coco_info['categories']}

# Print the class names
print("Class Names:")
for class_id, class_name in class_names.items():
    print(f"Class ID: {class_id}, Class Name: {class_name}")
# Out:
# Class Names:
# Class ID: 0, Class Name: Port-Status
# Class ID: 1, Class Name: Eth-Conn
# Class ID: 2, Class Name: Eth-Not-Conn
# Class ID: 3, Class Name: TEL-Conn
# Class ID: 4, Class Name: TEL-Not-Conn

# %% [markdown]
# This code defines a custom collate function for a data loader that deals with batches of images and their annotations, where each image may have a variable number of labels due to differing numbers of objects detected within them. The function:
#
# - Groups together images and their corresponding targets (annotations) from the batch.
# - Extracts the category IDs from the annotations to use as labels for each image.
# - Pads the labels for each image to ensure that every image in the batch has the same number of labels, using -1 as the padding value. This uniformity is necessary for batch processing in neural network models.
# - Returns a batch of images and their padded labels, ready for training or evaluation in a model.
#
# This approach ensures that the data fed into the model is consistently formatted, accommodating the inherent variability in the number of objects per image within datasets used for object detection tasks.

# %%
def custom_collate_fn(batch):
    images, targets = zip(*batch)
    
    # Extract category IDs as labels/classes from the target annotations
    labels = [[ann['category_id'] for ann in target] for target in targets]
#    print(f"\nlabels  is {labels}")

    # Pad labels with -1 so that each batch has the same number of labels
    padded_labels = [l + [-1]*(max_labels - len(l)) for l in labels]
#    print(f"\npadded_labels  is {padded_labels}")

    return torch.stack(images), torch.tensor(padded_labels)

# %% [markdown]
# This snippet sets up data loaders for both training and testing datasets using the previously defined custom collate function. The data loaders are responsible for efficiently loading the data in batches with the specified batch size and applying the custom collate function to handle batches with a variable number of labels per image. For the training data loader, data is shuffled to ensure diversity in the batches seen by the model during training, which helps in generalization. For the testing data loader, shuffling is disabled to maintain the order of the dataset, which can be important for evaluating model performance. The custom collate function ensures each batch has uniformly shaped targets by padding, facilitating training and evaluation with datasets where images contain different numbers of annotations.

# %%
# Create data loaders with custom collate function
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn)

# %% [markdown]
# This code defines a Convolutional Neural Network (CNN) model for image processing tasks. The CNN comprises layers designed to automatically and adaptively learn spatial hierarchies of features from input images. Here's a brief overview of its structure and functionality:
#
# - **Initialization (__init__):** The model initializes with two convolutional layers (conv1 and conv2) and two fully connected (linear) layers (fc1 and fc2). The convolutional layers are responsible for extracting features from the input images, while the fully connected layers perform classification based on these features.
# - **Convolutional Layers:** The first layer (conv1) takes an input with 3 color channels (assuming RGB images) and produces 16 feature maps using a kernel size of 3x3 with a stride of 1. The second layer (conv2) takes these 16 feature maps as input and outputs 32 feature maps, also with a 3x3 kernel and stride of 1. These layers help in capturing patterns such as edges, textures, and other visual elements from the images.
# - **Pooling:** After each convolutional layer, a max pooling operation reduces the spatial size of the representation, decreasing the number of parameters and computation in the network, and thereby controlling overfitting.
# - **Fully Connected Layers:** Before reaching the first fully connected layer (fc1), the feature map is flattened. The fc1 layer has 128 neurons and is followed by the output layer (fc2), which has a number of neurons equal to the maximum number of labels in the dataset, allowing the model to classify images into multiple categories based on the learned features.
# - **Forward Pass (forward):** Defines the forward propagation of the input through the CNN. It sequentially applies ReLU activations after convolutional layers, performs max pooling, flattens the output, and passes it through fully connected layers with ReLU activation between them.
#
# The model's architecture is designed to be adjusted based on the specific dimensions of the resized input images and the unique requirements of the dataset (e.g., the number of labels). This flexibility allows the CNN to be tailored to a wide range of image recognition tasks.

# %%
# Define CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1)
        self.conv2 = nn.Conv2d(16, 32, 3, 1)
        self.fc1 = nn.Linear(32*54*54, 128)  # Adjust the input size according to your resized image dimensions
        self.fc2 = nn.Linear(128, max_labels)  # Output layer with the maximum number of labels

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 32*54*54)  # Adjust the input size according to your resized image dimensions
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# This continuation sets up the necessary components for training the previously defined Convolutional Neural Network (CNN) model:
# - **Model Instantiation:** A new instance of the CNN model is created, preparing it for training and inference. This step initializes the model's weights and biases, setting it up for the upcoming training process.
# - **Loss Function:** The `nn.MultiLabelSoftMarginLoss` is specified as the loss function. This loss is suitable for multi-label classification tasks, where each label is treated independently, and the model predicts the presence or absence of each label in the image. The loss function calculates the difference between the model's predictions and the actual target values, guiding the model to adjust its parameters to minimize this difference over time.
# - **Optimizer:** The `Adam` optimizer is chosen to update the model's weights based on the computed gradients. Adam is a popular optimization algorithm in deep learning because it combines the advantages of two other extensions of stochastic gradient descent: Adaptive Gradient Algorithm (AdaGrad) and Root Mean Square Propagation (RMSProp). It is known for its efficiency in handling sparse gradients on noisy problems. The learning rate (`lr`) is set according to the predefined `learning_rate` hyperparameter, influencing the size of the steps the optimizer takes towards minimizing the loss function.
#
# By defining the model, loss function, and optimizer, the setup for training the CNN on a multi-label image classification task is complete. The next steps typically involve training the model on the training dataset using the defined data loaders and evaluating its performance on the test dataset to measure its accuracy and effectiveness in classifying images according to the specified labels.

# %%
# Instantiate the model
model = CNN()

# Define loss function and optimizer
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# This snippet outlines the training process for the Convolutional Neural Network (CNN) model, focusing on handling multi-label image classification. The training loop iterates over the dataset multiple times (epochs), each time processing batches of images and their corresponding labels.
#
# - **Epoch Iteration:** The outer loop iterates through the dataset for a predefined number of epochs, allowing the model to learn from the entire dataset multiple times.
# - **Batch Processing:** Within each epoch, the inner loop iterates over batches of images and labels. Each batch is processed through the model to generate predictions (outputs).
# - **One-Hot Encoding of Labels:** Since the task involves multi-label classification, labels are converted into a one-hot encoded format. This format matches the model's output, allowing for direct comparison. Labels for each image are encoded such that each label's presence is marked with a 1, while absence (or padding) is marked with a 0.
# - **Loss Calculation:** The loss is computed using the model's predictions and the one-hot encoded labels. This loss measures how well the model's predictions match the actual labels, guiding the optimization process.
# - **Optimization:** The backward pass calculates gradients for the model's parameters based on the loss. The optimizer then updates the model's weights to minimize the loss, using the learning rate to determine the size of the step towards loss minimization.
# - **Logging:** The loop prints out the loss at regular intervals, providing insights into how the model's performance improves over time.
# - **Completion:** After training through all epochs, the process concludes, and the model is considered trained, ready for evaluation or deployment.

# %%
# Training loop
total_steps = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):

        # Forward pass
        outputs = model(images)
        
        # Convert labels to one-hot encoded tensors
        labels_one_hot = torch.zeros(outputs.shape[0], max_labels)  # Assuming max_labels is the maximum number of labels
        for batch_idx, label_batch in enumerate(labels):
            for idx, label in enumerate(label_batch):
                if label != -1:
                    labels_one_hot[batch_idx, label] = 1
 
#        print(f"\noutput shape after loop is {outputs}")
        
#        print(f"\nlabels_one_hot shape after loop is {labels_one_hot}")
 
        # Calculate loss
        loss = criterion(outputs, labels_one_hot) 

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

#        if (i+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_steps}], Loss: {loss.item()}')

print('Finished Training')
# Out:
# Epoch [1/10], Step [1/18], Loss: 0.6953925490379333
# Epoch [1/10], Step [2/18], Loss: 0.5800410509109497
# Epoch [1/10], Step [3/18], Loss: 0.7747972011566162
# Epoch [1/10], Step [4/18], Loss: 1.2767571210861206
# Epoch [1/10], Step [5/18], Loss: 0.3531678318977356
# Epoch [1/10], Step [6/18], Loss: 0.4733739495277405
# Epoch [1/10], Step [7/18], Loss: 0.3368566036224365
# Epoch [1/10], Step [8/18], Loss: 0.21362152695655823
# Epoch [1/10], Step [9/18], Loss: 0.3257046937942505
# Epoch [1/10], Step [10/18], Loss: 0.34739813208580017
# Epoch [1/10], Step [11/18], Loss: 0.40003806352615356
# Epoch [1/10], Step [12/18], Loss: 0.4502297043800354
# Epoch [1/10], Step [13/18], Loss: 0.36195579171180725
# Epoch [1/10], Step [14/18], Loss: 0.32516318559646606
# Epoch [1/10], Step [15/18], Loss: 0.4769258499145508
# Epoch [1/10], Step [16/18], Loss: 0.4650411903858185
# Epoch [1/10], Step [17/18], Loss: 0.28603094816207886
# Epoch [1/10], Step [18/18], Loss: 0.42104488611221313
# Epoch [2/10], Step [1/18], Loss: 0.24791061878204346
# Epoch [2/10], Step [2/18], Loss: 0.22059696912765503
# Epoch [2/10], Step [3/18], Loss: 0.21236559748649597
# Epoch [2/10], Step [4/18], Loss: 0.40223631262779236
# Epoch [2/10], Step [5/18], Loss: 0.231228306889534
# Epoch [2/10], Step [6/18], Loss: 0.2715664803981781
# Epoch [2/10], Step [7/18], Loss: 0.13398736715316772
# Epoch [2/10], Step [8/18], Loss: 0.19763071835041046
# Epoch [2/10], Step [9/18], Loss: 0.6009079217910767
# Epoch [10/10], Step [11/18], Loss: 0.00015042237646412104
# Epoch [10/10], Step [12/18], Loss: 0.00020314534776844084
# Epoch [10/10], Step [13/18], Loss: 0.00033770943991839886
# Epoch [10/10], Step [14/18], Loss: 0.00022875248396303505
# Epoch [10/10], Step [15/18], Loss: 0.00027575637795962393
# Epoch [10/10], Step [16/18], Loss: 0.0003850882640108466
# Epoch [10/10], Step [17/18], Loss: 0.0002779156784527004
# Epoch [10/10], Step [18/18], Loss: 0.00035622474388219416
# Finished Training

# %%
model.eval()            
with torch.no_grad():
    total = 0
    correct = 0           
    
    for i, (images, labels) in enumerate(test_loader):
        # Forward pass
        outputs = model(images)
        print(f"\nlogits is {outputs}")


        # Convert outputs to predicted labels using argmax
        predicted_labels = torch.argmax(outputs, dim=1)
        print(f"\npredicted_labels is {predicted_labels}")

        # Flatten the labels tensor
        labels_flat = labels.view(-1)
        print(f"\nlabels_flat is {labels_flat}")

        # Ensure labels_flat and predicted_labels have compatible shapes for comparison
        predicted_labels = predicted_labels.unsqueeze(1).expand(-1, labels_flat.size(0))
        print(f"\npredicted_labels is {predicted_labels}")

        # Calculate accuracy
        total += labels_flat.size(0)
        correct += torch.sum(labels_flat == predicted_labels.squeeze()).item()

    accuracy = correct / total
    
    print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# logits is tensor([[-35.4060,   4.8578,  12.3973,  -2.3474,  18.6544, -30.3625],
#         [-37.8067,   2.0152,  12.0022,  -0.3005,  16.6834, -28.4175],
#         [-40.6194,   5.2102,  13.1429,  -4.4290,  15.2267, -29.0108],
#         [-33.5529,   0.2645,   5.4808,  -2.9439,  10.4664, -22.3965]])
#
# predicted_labels is tensor([4, 4, 4, 4])
#
# labels_flat is tensor([ 3,  4,  1,  1,  2,  2,  4,  4,  2,  2,  2,  2,  4,  4,  1,  2,  2, -1,
#          3,  2,  2, -1, -1, -1])
#
# predicted_labels is tensor([[4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#         [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#         [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#         [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]])
#
# logits is tensor([[-34.2780,   3.6210,   5.6375,   3.3390,  10.4850, -24.4280],
#         [-31.9222,   3.1985,   8.7384,   1.1024,  12.9561, -24.2745],
#         [-34.6463,  -3.3063,   8.9459,  -4.4625,   4.8677, -21.4449],
#         [-28.1268,   0.5701,   7.2723,  -2.8794,  12.0506, -21.2410]])
#
# predicted_labels is tensor([4, 4, 2, 4])
#
# labels_flat is tensor([ 4,  4,  2,  2,  1,  1,  3,  4,  2,  2,  1, -1,  4,  4,  2,  2,  2, -1,
#          4,  4,  2,  2, -1, -1])
#
# predicted_labels is tensor([[4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#         [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#         [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#         [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]])
#
# logits is tensor([[-3.5772e+01,  6.0190e-03,  7.9324e+00, -2.8058e+00,  1.1209e+01,
#          -2.4794e+01],
#         [-2.5437e+01, -8.3306e-01,  4.7464e+00, -4.1206e+00,  4.4320e+00,
#          -1.5839e+01]])
#
# predicted_labels is tensor([4, 2])
#
# labels_flat is tensor([ 3,  4,  2,  2,  2,  1,  4,  4,  1,  1,  2, -1])
#
# predicted_labels is tensor([[4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#         [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]])
# Test Accuracy: 95.00%
